# %% [markdown]
# #### Import libraries

# %%
# !pip install ultralytics
from ultralytics import YOLO
import os

# %% [markdown]
# #### Import model and assign dataset

# %%
model = YOLO('/kaggle/input/ad_detection_yolov8/pytorch/default/1/best.pt')
images_dir = '/kaggle/input/ad-detect-test-images'

# %% [markdown]
# #### Run predict to detect ads on screenshots

# %%
results = model.predict(source=images_dir, save=True, save_txt=True)
